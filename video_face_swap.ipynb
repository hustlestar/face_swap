# %%
# %cd roop
# Out:
# G:\OLD_DISK_D_LOL\Projects\media-empire\notebooks\roop
# G:\OLD_DISK_D_LOL\Projects\media-empire\notebooks\venv\lib\site-packages\IPython\core\magics\osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# %pwd
# Out:
# 'G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop'

# %%
# !which python

# %%
# !python run.py --target G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\input\\1.mp4 --source G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\input\\AS.png -o G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\output\\1swapped.mp4 --execution-provider cuda --frame-processor face_swapper face_enhancer

# %%
# !python run.py --target G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\input\\1.mp4 --source G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\input\\AS.png -o G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\output\\1swapped.mp4 --execution-provider cuda --frame-processor face_swapper face_enhancer
# Out:
# download_path: C:\Users\hustlestar/.insightface\models\buffalo_l
# ...
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CUDAExecutionProvider': {'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'device_id': '0', 'gpu_external_alloc': '0', 'enable_cuda_graph': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_free': '0', 'gpu_external_empty_cache': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'cudnn_conv_use_max_workspace': '1', 'cudnn_conv1d_pad_to_nc1d': '0', 'tunable_op_enable': '0', 'tunable_op_tuning_enable': '0', 'enable_skip_layer_norm_strict_mode': '0'}, 'CPUExecutionProvider': {}}
# find model: C:\Users\hustlestar/.insightface\models\buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# ...

# %%
# !python --version
# Out:
# Python 3.10.6

# %%
# !python run.py --target G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\input\\1.mp4 --source G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\input\\AS.png -o G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\output\\1swapped.mp4 --execution-provider cuda --frame-processor face_swapper face_enhancer
# Out:
# Applied providers: ['CUDAExecutionProvider', 'CPUExecutionProvider'], with options: {'CUDAExecutionProvider': {'do_copy_in_default_stream': '1', 'cudnn_conv_algo_search': 'EXHAUSTIVE', 'device_id': '0', 'gpu_external_alloc': '0', 'enable_cuda_graph': '0', 'gpu_mem_limit': '18446744073709551615', 'gpu_external_free': '0', 'gpu_external_empty_cache': '0', 'arena_extend_strategy': 'kNextPowerOfTwo', 'cudnn_conv_use_max_workspace': '1', 'cudnn_conv1d_pad_to_nc1d': '0', 'tunable_op_enable': '0', 'tunable_op_tuning_enable': '0', 'enable_skip_layer_norm_strict_mode': '0'}, 'CPUExecutionProvider': {}}
# find model: C:\Users\hustlestar/.insightface\models\buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# ...

# %%
version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 version
#
# NameError: name 'version' is not defined

# %%
# !python run.py --target G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\input\\1.mp4 --source G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\input\\AS.png -o G:\\OLD_DISK_D_LOL\\Projects\\media-empire\\notebooks\\roop\\data\\output\\1swapped.mp4 --execution-provider cuda --frame-processor face_swapper face_enhancer

# %%
version
